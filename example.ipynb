# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1

# %%
from IPython.display import display

# %%
from jupyter_host_filebrowser import HostFilePicker
w = HostFilePicker()

selected = []
def obs(change):
    """Record selected files."""
    selected.clear()
    selected.extend(change['new'])
w.observe(obs, names='selected')

display(w)

# %%
w.selected

# %%
selected
